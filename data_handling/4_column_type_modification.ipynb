# %%
# gpu number setting
import os
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ["CUDA_VISIBLE_DEVICES"] = '1' ## gpu 번호 셋팅 윤건 :0, 기준 : 1, 준형 :2,

# Gpu growth setting
import tensorflow as tf
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)


# tensorflow & keras version check
print('tensorflow version : ' , tf.__version__)
print('keras version : ' , tf.keras.__version__)

# tensorflow gpu available check 
print('GPU available ? : ', tf.test.is_gpu_available(cuda_only=False, min_cuda_compute_capability=None))
# Out:
# tensorflow version :  2.3.1
# keras version :  2.4.0
# GPU available ? :  True

# %%
import pandas as pd
import tqdm
import numpy as np
import pickle

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
with open('../../Data/movie_201118_table_3.pickle', 'rb') as f:
    raw = pickle.load(f)

# %%
str_col = ['sa_id', 'album_id', 'buy_seg']
int_col = ['release_date', 'run_time', 'movie_meta_price', 'i30_meta_price', 'buy_tot']
float_col = ['amt_1_4', 'amt_2_4', 'amt_3_4', 'amt_4_4']

# %%
raw[str_col] = raw[str_col].astype(str)
raw[int_col] = raw[int_col].astype(int)
raw[float_col] = raw[float_col].astype(float)

# %%
set(raw['amt_2_4'])
# Out:
# {0.0,
#  0.027777778,
#  0.041666668,
#  0.05,
#  0.055555556,
#  0.0625,
#  0.06666667,
#  0.071428575,
#  0.07692308,
#  0.083333336,
#  0.09090909,
#  0.09375,
#  0.0952381,
#  0.1,
#  0.10344828,
#  0.11111111,
#  0.125,
#  0.13333334,
#  0.14285715,
#  0.14814815,
#  0.15384616,
#  0.15789473,
#  0.16666667,
#  0.18181819,
#  0.1863354,
#  0.1875,
#  0.1904762,
#  0.2,
#  0.20754717,
#  0.21428572,
#  0.22222222,
#  0.23076923,
#  0.23529412,
#  0.24,
#  0.24242425,
#  0.25,
#  0.26086956,
#  0.26288658,
#  0.2631579,
#  0.26666668,
#  0.27272728,
#  0.2857143,
#  0.29166666,
#  0.29411766,
#  0.3,
#  0.30769232,
#  0.3125,
#  0.31578946,
#  0.32,
#  0.33333334,
#  0.35,
#  0.3529412,
#  0.35714287,
#  0.36,
#  0.36363637,
#  0.37096775,
#  0.375,
#  0.37931034,
#  0.3846154,
#  0.3846154000000001,
#  0.3888889,
#  0.4,
#  0.41666666,
#  0.42857143,
#  0.42920354,
#  0.4347826,
#  0.4375,
#  0.44444445,
#  0.45454547,
#  0.46153846,
#  0.46341464,
#  0.46666667,
#  0.47368422,
# ...

# %%
with open('../../Data/movie_201118_table_4.pickle', 'wb') as f:
    pickle.dump(raw, f)
